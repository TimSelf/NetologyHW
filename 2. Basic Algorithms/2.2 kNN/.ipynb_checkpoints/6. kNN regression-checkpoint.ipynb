# %% [markdown]
# ## Пример решения задачи регрессии

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors

# %%
# получим столбец чисел, равномерно распределенных на интервале [0, 1) и упорядоченных по возрастанию
X = np.sort( 5 * np.random.rand(40, 1), axis = 0 )

# %%
X[:5]
# Out:
# array([[0.00906464],
#        [0.06543481],
#        [0.0983147 ],
#        [0.2247333 ],
#        [0.26426149]])

# %%
# зададим какую-нибудь функцию
# функция ravel() применена, чтобы преобразовать вложенный лист np.sin( X ) в простой массив
y = np.sin( X ).ravel()
y
# Out:
# array([ 0.00906452,  0.06538812,  0.0981564 ,  0.22284637,  0.26119647,
#         0.3658614 ,  0.55634184,  0.69610589,  0.81639881,  0.92941106,
#         0.94758878,  0.98625131,  0.98995302,  0.94484544,  0.911444  ,
#         0.88716576,  0.64298241,  0.53637577,  0.53441237,  0.41864516,
#         0.32604877,  0.17978364,  0.01509195, -0.06332568, -0.24575129,
#        -0.29776903, -0.3692798 , -0.63113979, -0.73016587, -0.76948432,
#        -0.86856527, -0.8689263 , -0.93658888, -0.96670851, -0.99859956,
#        -0.99866429, -0.995011  , -0.98627043, -0.97935071, -0.97050369])

# %%
np.sin( X )[:5]
# Out:
# array([[0.00906452],
#        [0.06538812],
#        [0.0981564 ],
#        [0.22284637],
#        [0.26119647]])

# %%
plt.plot( X, y )
plt.show()

# %%
# добавим шум к зависимой переменной
# к каждому пятому элементу добавляем случайное число
y[::5] += 1 * ( 0.5 - np.random.rand( 8 ) )

# %%
plt.plot( X, y )
plt.show()

# %%
# определим набор значений, на которых надо будет делать предсказания
T = np.linspace( 0, 5, 500 )[:, np.newaxis] # 500 точек в интервале от 0 до 5

# %%
T[:5]
# Out:
# array([[0.        ],
#        [0.01002004],
#        [0.02004008],
#        [0.03006012],
#        [0.04008016]])

# %%
# задаем количество соседей, которое будем учитывать в KNN
n_neighbors = 5

# %%
knn = neighbors.KNeighborsRegressor( n_neighbors, weights = 'uniform' )
y_ = knn.fit( X, y ).predict( T )

# %%
plt.scatter(X, y, c='k', label='data')
plt.plot(T, y_, c='g', label='prediction')
plt.axis('tight')
plt.legend()
plt.title("KNeighborsRegressor (k = %i, weights = '%s')" % (n_neighbors, 'uniform'))
plt.show()

# %% [markdown]
# Для варианта с весами видно сильное влияние расстояния

# %%
knn = neighbors.KNeighborsRegressor( n_neighbors, weights = 'distance' )
y_ = knn.fit( X, y ).predict( T )

plt.scatter(X, y, c='k', label='data')
plt.plot(T, y_, c='g', label='prediction')
plt.axis('tight')
plt.legend()
plt.title("KNeighborsRegressor (k = %i, weights = '%s')" % (n_neighbors, 'distance'))
plt.show()
